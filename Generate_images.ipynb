# %%
#@title Librerias
import os
import cv2
import numpy as np
from tqdm import tqdm
from google.colab import drive

# %%
#@title Repositorio
# !git clone https://github.com/OscarMigue9/IA_2.git
# Out:
# Cloning into 'IA_2'...
# remote: Enumerating objects: 27, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 27 (delta 4), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (27/27), 2.53 MiB | 5.43 MiB/s, done.
# Resolving deltas: 100% (4/4), done.

# %%
#@title Drive
drive.mount('/content/drive')
input_dir = '/content/drive/MyDrive/UIS/8_semestre/IA_2/Proyecto/images/blur'
gt_dir = "/content/IA_2/Images/gt_images"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Montar Drive

# Obtener lista de imágenes desde GitHub
image_files = [f for f in os.listdir(gt_dir) if f.endswith(('.jpg', '.jpeg', '.png', '.bmp', '.tiff'))]

if not image_files:
    raise FileNotFoundError(f"No image files found in the directory: {gt_dir}")

# Definir kernel de blur de movimiento
kernel_size = 15
kernel = np.zeros((kernel_size, kernel_size), dtype=np.float32)
kernel[int((kernel_size - 1)/2), :] = 1
kernel = kernel / kernel.sum()

print(f"Applying motion blur to images in {gt_dir} and saving to {input_dir}...")

for filename in tqdm(image_files):
    img_path = os.path.join(gt_dir, filename)
    img = cv2.imread(img_path)

    if img is None:
        print(f"Warning: Could not read image file: {img_path}. Skipping.")
        continue

    # Aplicar blur
    motion_blur_img = cv2.filter2D(img, -1, kernel)

    # Guardar en Drive
    output_path = os.path.join(input_dir, filename)
    cv2.imwrite(output_path, motion_blur_img)

print("Motion blur applied to all images and saved in Google Drive.")
# Out:
# Applying motion blur to images in /content/IA_2/Images/gt_images and saving to /content/drive/MyDrive/UIS/8_semestre/IA_2/Proyecto/images/blur...
# 100%|██████████| 2/2 [00:02<00:00,  1.27s/it]
# Motion blur applied to all images and saved in Google Drive.
